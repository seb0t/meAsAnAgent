# %%
from llm.gemini_client import GeminiLLMClient
from agent import Agent
import tools.math_tools
import tools.conversion_tools
agent = Agent(llm_client=GeminiLLMClient())
# Out:
# /Users/qwerty/coding/meAsAnAgent/agent_core/prompts/prompts.py:141: UserWarning: Field name "schema" in "GodSchema" shadows an attribute in parent "BaseModel"
#   class GodSchema(BaseModel):

# %%
response = (agent.ask("quanto fa 4 x 12 + cane?"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = (agent.ask("quanto fa 4 x 12 + cane?"))
#
# File ~/coding/meAsAnAgent/agent_core/agent.py:24, in Agent.ask(self, prompt)
#      22 error_counter = 0
#      23 for item in response:
# ---> 24     if item.get("errore"):
#      25         error_counter += 1
#      26         # Mando il risultato al modello per continuare
#
# AttributeError: 'str' object has no attribute 'get'

# %%
agent.messages

# %%
agent.messages

# %%
agent.response_log

# %%
mixed_response = agent.ask("fammi un esempio di una conversione e risolvila utilizzando le tue funzioni, per esempio il calcolo di 5 miglia in km. poi dimmi i capoluoghi di provincia del friuli venezia giulia.e infine dimmi quanto fa 40 diviso 3.")

# %%
agent.messages

# %%
mixed_response
